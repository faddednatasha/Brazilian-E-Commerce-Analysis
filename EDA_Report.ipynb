# %% [markdown]
# <a href="https://colab.research.google.com/github/faddednatasha/Brazilian-E-Commerce-Analysis/blob/main/EDA_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  EDA Report: E-Commerce Dataset
#
# ---
#
# ## 1. Dataset at a Glance
#
# We’re working with a large e-commerce dataset that captures everything from **orders and payments** to **deliveries and customer reviews**.
#
# - **Size:** ~116,000 orders placed by 100,000+ customers.
# - **What’s inside?**
#   - **Orders & Customers** → who bought what, when, and from where.
#   - **Deliveries** → when packages were shipped and delivered (and if they were late).
#   - **Products & Prices** → category and cost of items.
#   - **Payments** → type (credit, debit, installments) and installments count.
#   - **Reviews** → customer satisfaction (1–5 stars).
#
# Think of it as a complete journey: from clicking "buy" → to waiting for delivery → to leaving a review.
#
# ---
#
# ## 2. How We Explored the Data
#
# Our plan was simple:
# 1. **Get to know the data** – check for missing values, outliers.
# 2. **Customer behavior** – where they live, how they pay.
# 3. **Delivery performance** – how late deliveries affect reviews.
# 4. **Product analysis** – what sells more and in which categories.
# 5. **Trends over time** – weekday vs weekend shopping.
# 6. **Test assumptions** – run statistical tests to back up insights.
#
# ---
#
# ## 3. Cleaning & Feature Engineering
#
# To make the dataset analysis-ready, we did a few tweaks:
#
# - Filled or dropped missing dates.
# - Created new features like:
#   - `delivery_delay` → days late (if any).
#   - `is_late` → flagging delayed orders.
#   - `order_day_of_week` + `is_weekend` → to study time patterns.
# - Encoded categorical values (payment types, states) for easier analysis.
#
# ---
#
# ## 4. What We Found (EDA Highlights)
#
# ###  Reviews
# - Most customers left **4–5 star reviews**.
# - But when deliveries were late, reviews dropped **dramatically**.
#
# ###  Payment Behavior
# - Majority paid in **single installment**.
# - Installments were popular in **electronics & furniture**, i.e., high-ticket items.
#
# ###  Sales Trends
# - Sales were **slightly higher on weekdays**.
# - Mid-week (Tuesday–Thursday) saw the **highest activity**.
#
# ###  Customer Locations
# - Customers spread across **23 states**.
# - **Urban states** had quicker deliveries, while **remote states** faced more delays.
#
# ---
#
# ## 5. Hypothesis Testing
#
# We didn’t just look at trends — we tested them statistically:
#
# ### H1: Delivery Delays vs Reviews
# - **Finding:** Late deliveries = lower ratings.
# - Each day of delay shaved off ~0.013 rating points.
# ✅ Strong evidence: delivery time directly affects satisfaction.
#
# ### H2: Installments vs Category
# - **Finding:** Installments heavily used in **high-priced categories**.
# ✅ Confirmed: not all products are equal when it comes to financing.
#
# ### H3: Weekday vs Weekend Sales
# - **Finding:** Weekdays see **slightly higher sales**.
# ✅ Confirmed: small but consistent difference.
#
# ### H4: Customer Location vs Delivery Delays
# - **Finding:** State does matter, but only explains a **small fraction** of delays.
# ✅ Confirmed: logistics complexity is beyond just geography.
#
# ---
#
# ## 6. Key Insights
#
# 1. **Timely deliveries = happy customers.**
#    - Late orders kill reviews.
# 2. **High-value products rely on installments.**
#    - Electronics/furniture buyers prefer flexible payments.
# 3. **Weekdays bring more sales.**
#    - Consider adjusting marketing/ads around this.
# 4. **Location influences delays, but not the whole story.**
#    - Delivery partners and logistics play a bigger role.
#
# ---
#
# ## 7. Wrapping Up & Next Steps
#
# This dataset gave us a clear picture of customer behavior, operations, and challenges.
#
# - **Focus areas:**
#   - Improve delivery speed to protect ratings.
#   - Push installment offers for expensive items.
#   - Optimize weekday marketing spend.
#   - Deep-dive into logistics bottlenecks.
#
# - **What’s next?**
#   - Build **predictive models** for delivery delays & review scores.
#   - Do a **cohort analysis** to understand repeat buyers.
#   - Explore **recommendation systems** for product suggestions.
#
# ---
#
# 👉 In short: Deliver faster, understand your customers’ spending habits, and fine-tune operations. That’s how this dataset points toward better customer satisfaction and business growth.
